# %% [markdown]
# Tensor Flow version setup

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %% [markdown]
# Imports that are needed

# %%
import sys
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Use this to upload the model and image files

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-028352cb-135e-4382-a5c1-1a85ec0fd560" name="files[]" multiple disabled />
#      <output id="result-028352cb-135e-4382-a5c1-1a85ec0fd560">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image.png to image.png
# Saving notMNIST.h5 to notMNIST (1).h5

# %% [markdown]
# Google Collab will not overwrite files so you'll need to remove olds ones with command line calls

# %%
# !rm "image.png"
#!rm "MNIST.h5"
# !rm "notMNIST.h5"
# Out:
# rm: cannot remove 'image.png': No such file or directory

# %% [markdown]
# Determine the arguments
# A weird way to do a notebook but lets code match non notebook code

# %%
sys.argv = ["", input("Dataset:"), input("Model:"), input("Image:"), input("Class index:")]
# Out:
# Dataset:notMNIST
# Model:notMNIST.h5
# Image:image.png
# Class index:0

# %%
def check_args():
     if(len(sys.argv) != 5):
          print("Usage python predict.py <MNIST,notMNIST> <model.h5> <image.png> <prediction class index>")
          sys.exit(1)
     if sys.argv[1] == "MNIST":
          print("--Dataset MNIST--")
          class_names = list(range(10))
     elif sys.argv[1] == "notMNIST":
          print("--Dataset notMNIST--")
          class_names = ["A","B","C","D","E","F","G","H","I","J"]
     else:
          print(f"Choose MNIST or notMNIST, not {sys.argv[1]}")
          sys.exit(2)
     if sys.argv[2][-3:] != ".h5":
          print(f"{sys.argv[2]} is not a h5 extension")
          sys.exit(3)
     if sys.argv[3][-4:] != ".png":
          print(f"{sys.argv[3]} is not a png extension")
          sys.exit(3)
     img = plt.imread(sys.argv[3])
     if len(img.shape) != 2:
          print("Image is not grey scale!")
          sys.exit(4)
     if img.shape != (28,28):
          print("Image is not 28 by 28!")
          sys.exit(4)
     if not sys.argv[4].isdigit():
          print(f"{sys.argv[4]} is not an integer (0-9)")
          sys.exit(3)
     if int(sys.argv[4]) < 0 or int(sys.argv[4]) > 9 :
          print(f"{sys.argv[4]} is not an integer (0-9)")
          sys.exit(3)
     return class_names

# %% [markdown]
# Completed functions to plot for you

# %%
def plot(class_names, prediction, true_label, predicted_label, img):
    plt.figure(figsize=(6,3))
    plt.subplot(1,2,1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    predicted_label = np.argmax(prediction)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],100*np.max(prediction),class_names[true_label]),color=color)
    plt.subplot(1,2,2)
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(class_names, prediction, color="#777777")
    plt.ylim([0, 1])
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %% [markdown]
# Finish the missing parts of function to predict output from input

# %%
def main():
     class_names = check_args()
     print(f"--Load Model {sys.argv[2]}--")
     #Load the model that should be in sys.argv[2]
     model = tf.keras.models.load_model(sys.argv[2]) # line added
    #  model.summary()
     print(f"--Load Image {sys.argv[3]}--")
     img = plt.imread(sys.argv[3])
     if np.amax(img.flatten()) > 1:
          img = img/255
     img = 1 - img
     print(f"--Predict as Class {sys.argv[4]}--")
     predict(model, class_names, img, int(sys.argv[4]))

def predict(model, class_names, img, true_label):
    img = np.array([img])
    #Replace these two lines with code to make a prediction
    img = img.reshape(img.shape[0], 28, 28, 1) # line added
    img = img.astype('float32') # line added
    img = img / 255.0 # line added
    prediction = model.predict(img)[0] # line added
    print(prediction)
    
    #Determine what the predicted label is
    predicted_label = prediction.argmax()  # line changed
    print(predicted_label)
    img = img.reshape(img.shape[0], 28, 28) # line added
    plot(class_names, prediction, true_label, predicted_label, img[0])
    plt.show()
main()
# Out:
# --Dataset notMNIST--
# --Load Model notMNIST.h5--
# --Load Image image.png--
# --Predict as Class 0--
# [0.14365944 0.14328197 0.07668222 0.00637824 0.01523197 0.11228725
#  0.03158905 0.2509961  0.16899133 0.05090246]
# 7

# %% [markdown]
# This can be used to see a traceback if the code ends with sys.exit(1)

# %%
# %tb
